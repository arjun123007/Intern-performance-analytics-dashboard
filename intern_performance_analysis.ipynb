# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\ELCOT\Downloads\archive\Intern_Performance_Data.csv")
data.head()
# Out:
#    Employee_ID        Department  Gender  Age   Job_Title Hire_Date  \
# 0            1                IT    Male   55  Specialist   03:05.6
# 1            2           Finance    Male   29   Developer   03:05.6
# 2            3           Finance    Male   55  Specialist   03:05.6
# 3            4  Customer Support  Female   48     Analyst   03:05.6
# 4            5       Engineering  Female   36     Analyst   03:05.6
#
#    Years_At_Company Education_Level  Performance_Score  Monthly_Stipend  \
# 0                 2     High School                  5             6750
# 1                 0     High School                  5             7500
# 2                 8     High School                  3             5850
# 3                 7        Bachelor                  2             4800
# 4                 3        Bachelor                  2             4800
#
#    Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  Sick_Days  \
# ...

# %%
data.shape
# Out:
# (100000, 20)

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Department', 'Gender', 'Age', 'Job_Title', 'Hire_Date',
#        'Years_At_Company', 'Education_Level', 'Performance_Score',
#        'Monthly_Stipend', 'Work_Hours_Per_Week', 'Projects_Handled',
#        'Overtime_Hours', 'Sick_Days', 'Remote_Work_Frequency', 'Team_Size',
#        'Training_Hours', 'Promotions', 'Employee_Satisfaction_Score',
#        'Resigned'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  object
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Stipend              100000 non-null  int64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# Employee_ID                    0
# Department                     0
# Gender                         0
# Age                            0
# Job_Title                      0
# Hire_Date                      0
# Years_At_Company               0
# Education_Level                0
# Performance_Score              0
# Monthly_Stipend                0
# Work_Hours_Per_Week            0
# Projects_Handled               0
# Overtime_Hours                 0
# Sick_Days                      0
# Remote_Work_Frequency          0
# Team_Size                      0
# Training_Hours                 0
# Promotions                     0
# Employee_Satisfaction_Score    0
# Resigned                       0
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
data.columns = data.columns.str.strip()

# %%
data['Hire_Date'] = pd.to_datetime(data['Hire_Date'])

# %%
data['Hire_Year'] = data['Hire_Date'].dt.year
data['Hire_Month'] = data['Hire_Date'].dt.month

# %%
data.to_csv("Intern_Performance_Data.csv", index=False)

# %%
data = data.rename(columns={"Employee_Satisfaction_Score": "Intern_Satisfaction_Score"})

# %%
data.to_csv(r"C:\Users\ELCOT\Downloads\archive\Intern_Performance_Data.csv", index=False)
