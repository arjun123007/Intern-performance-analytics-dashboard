# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\ELCOT\OneDrive\Desktop\Rynix proj 1\Intern_Performance_Data.csv")
data.head()
# Out:
#    Employee_ID        Department  Gender  Age   Job_Title  \
# 0            1                IT    Male   55  Specialist
# 1            2           Finance    Male   29   Developer
# 2            3           Finance    Male   55  Specialist
# 3            4  Customer Support  Female   48     Analyst
# 4            5       Engineering  Female   36     Analyst
#
#              Hire_Date  Years_At_Company Education_Level  Performance_Score  \
# 0  2026-03-18 03:05:36                 2     High School                  5
# 1  2026-03-18 03:05:36                 0     High School                  5
# 2  2026-03-18 03:05:36                 8     High School                  3
# 3  2026-03-18 03:05:36                 7        Bachelor                  2
# 4  2026-03-18 03:05:36                 3        Bachelor                  2
#
#    Monthly_Stipend  ...  Overtime_Hours  Sick_Days  Remote_Work_Frequency  \
# 0             6750  ...              22          2                      0
# ...

# %%
data.describe()
# Out:
#          Employee_ID            Age  Years_At_Company  Performance_Score  \
# count  100000.000000  100000.000000     100000.000000      100000.000000
# mean    50000.500000      41.029410          4.476070           2.995430
# std     28867.657797      11.244121          2.869336           1.414726
# min         1.000000      22.000000          0.000000           1.000000
# 25%     25000.750000      31.000000          2.000000           2.000000
# 50%     50000.500000      41.000000          4.000000           3.000000
# 75%     75000.250000      51.000000          7.000000           4.000000
# max    100000.000000      60.000000         10.000000           5.000000
#
#        Monthly_Stipend  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# count    100000.000000        100000.000000     100000.000000   100000.000000
# mean       6403.211000            44.956950         24.431170       14.514930
# ...

# %%
data.mean(numeric_only=True)
# Out:
# Employee_ID                  50000.500000
# Age                             41.029410
# Years_At_Company                 4.476070
# Performance_Score                2.995430
# Monthly_Stipend               6403.211000
# Work_Hours_Per_Week             44.956950
# Projects_Handled                24.431170
# Overtime_Hours                  14.514930
# Sick_Days                        7.008550
# Remote_Work_Frequency           50.090500
# Team_Size                       10.013560
# Training_Hours                  49.506060
# Promotions                       0.999720
# Intern_Satisfaction_Score        2.999088
# Resigned                         0.100100
# Hire_Year                     2026.000000
# Hire_Month                       3.000000
# dtype: float64

# %%
data.corr(numeric_only=True)
# Out:
#                            Employee_ID       Age  Years_At_Company  \
# Employee_ID                   1.000000  0.004010         -0.007175
# Age                           0.004010  1.000000          0.000078
# Years_At_Company             -0.007175  0.000078          1.000000
# Performance_Score            -0.002077  0.001598          0.001598
# Monthly_Stipend              -0.002050  0.002757         -0.000645
# Work_Hours_Per_Week          -0.000968 -0.003050          0.002578
# Projects_Handled             -0.000706 -0.001726          0.002963
# Overtime_Hours               -0.005254  0.001875          0.001965
# Sick_Days                     0.000745  0.006981         -0.004371
# Remote_Work_Frequency        -0.000347 -0.004672         -0.002443
# Team_Size                     0.002027 -0.003411          0.003250
# Training_Hours               -0.002966  0.002045          0.002696
# Promotions                   -0.000778 -0.002888         -0.002737
# ...

# %%
data.groupby('Department')['Performance_Score'].mean()
# Out:
# Department
# Customer Support    2.997121
# Engineering         3.020263
# Finance             2.981161
# HR                  2.997354
# IT                  3.000000
# Legal               2.981741
# Marketing           2.980653
# Operations          3.006797
# Sales               2.994336
# Name: Performance_Score, dtype: float64

# %%
data['Resigned'].value_counts()
# Out:
# Resigned
# False    89990
# True     10010
# Name: count, dtype: int64

# %%
data[['Performance_Score','Intern_Satisfaction_Score']].corr()
# Out:
#                            Performance_Score  Intern_Satisfaction_Score
# Performance_Score                   1.000000                   0.001696
# Intern_Satisfaction_Score           0.001696                   1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.groupby('Department')['Performance_Score'].mean().plot(kind='bar')
plt.title("Average Performance by Department")
plt.show()

# %%
data['Age'].plot(kind='hist')
plt.title("Age Distribution")
plt.show()

# %%
data['Resigned'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Resignation Distribution")
plt.show()

# %%
plt.scatter(data['Work_Hours_Per_Week'], data['Performance_Score'])
plt.xlabel("Work Hours")
plt.ylabel("Performance Score")
plt.title("Work Hours vs Performance")
plt.show()

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\ELCOT\OneDrive\Desktop\Rynix proj 1\Sprint_1\Intern_Performance_Data.csv")

# %%
total_employees = data.shape[0]
avg_performance = data['Performance_Score'].mean()
avg_satisfaction = data['Intern_Satisfaction_Score'].mean()
total_projects = data['Projects_Handled'].sum()
avg_stipend = data['Monthly_Stipend'].mean()
attrition_rate = (data['Resigned'].mean()) * 100

print(total_employees, avg_performance, avg_satisfaction, total_projects, avg_stipend, attrition_rate)
# Out:
# 100000 2.99543 2.9990883999999998 2443117 6403.211 10.01
